# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('experimental_data/additive_adaptation_contrast/metrics.csv')
df
# Out:
#     contrast  epoch  repeat_noise  test_acc  step
# 0        0.8      1          True    0.7288     0
# 1        0.8      1         False    0.7496     1
# 2        1.0      1          True    0.7600     2
# 3        1.0      1         False    0.7752     3
# 4        0.2      1          True    0.5704     4
# 5        0.2      1         False    0.5832     5
# 6        0.4      1          True    0.6700     6
# 7        0.4      1         False    0.6796     7
# 8        0.6      1          True    0.7264     8
# 9        0.6      1         False    0.7268     9
# 10       0.8      2          True    0.7784    10
# 11       0.8      2         False    0.7912    11
# 12       1.0      2          True    0.7932    12
# 13       1.0      2         False    0.8012    13
# 14       0.2      2          True    0.6188    14
# 15       0.2      2         False    0.6060    15
# 16       0.4      2          True    0.7212    16
# 17       0.4      2         False    0.7096    17
# ...

# %%
sns.relplot(data=df, x='contrast', y='test_acc', hue='repeat_noise', row='epoch', kind='line', markers=True, size=200)
plt.title('Fashion MNIST different epochs')
# Out:
# Text(0.5, 1.0, 'Fashion MNIST different epochs')
