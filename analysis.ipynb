# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('experimental_data/cifar10_contrast/metrics.csv')
df
# Out:
#     contrast  epoch  repeat_noise  test_acc  step
# 0        0.8      2          True    0.3688     0
# 1        0.8      2         False    0.3700     1
# 2        1.0      2          True    0.4236     2
# 3        1.0      2         False    0.4272     3
# 4        0.2      2          True    0.2164     4
# ..       ...    ...           ...       ...   ...
# 58       0.6     40          True    0.6368    58
# 59       0.6     40         False    0.4840    59
# 60       0.8     40          True    0.6388    60
# 61       0.8     40         False    0.5392    61
# 62       1.0     40          True    0.6904    62
#
# [63 rows x 5 columns]

# %%
sns.relplot(data=df, x='contrast', y='test_acc', hue='repeat_noise', col='epoch', kind='line', markers=True, )
# set title
plt.subplots_adjust(top=0.9)
plt.suptitle('Cifar-10 Accuracy by Epochs and Contrast', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Cifar-10 Accuracy by Epochs and Contrast')

# %%
a = 1, 2, 3
a
# Out:
# (1, 2, 3)

# %%
def afun(a, b, c):
    print(a, b, c)

# %%
afun(*a)
# Out:
# 1 2 3

# %%
a, *b = 1,2,

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2]
