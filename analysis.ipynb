# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('debug_div_norm/temp_div_norm/version_0/metrics.csv')
df
# Out:
#     contrast  epoch  repeat_noise  test_acc  step
# 0        0.8      2          True    0.7825     0
# 1        0.8      6          True    0.8063     1
# 2        0.8     25          True    0.8320     2
# 3        0.8      2         False    0.7824     3
# 4        0.8      6         False    0.8089     4
# 5        0.8     25         False    0.8346     5
# 6        1.0      2          True    0.7896     6
# 7        1.0      6          True    0.8298     7
# 8        1.0     25          True    0.8455     8
# 9        1.0      2         False    0.8040     9
# 10       1.0      6         False    0.8265    10
# 11       1.0     25         False    0.8502    11
# 12       0.2      2          True    0.6867    12
# 13       0.2      6          True    0.7372    13
# 14       0.2     25          True    0.7764    14
# 15       0.2      2         False    0.5941    15
# 16       0.2      6         False    0.6261    16
# 17       0.2     25         False    0.6547    17
# 18       0.4      2          True    0.7278    18
# 19       0.4      6          True    0.7809    19
# 20       0.4     25          True    0.8169    20
# 21       0.4      2         False    0.6660    21
# 22       0.4      6         False    0.7160    22
# 23       0.4     25         False    0.7495    23
# 24       0.6      2          True    0.7514    24
# 25       0.6      6          True    0.7737    25
# 26       0.6     25          True    0.8236    26
# 27       0.6      2         False    0.7327    27
# 28       0.6      6         False    0.7574    28
# 29       0.6     25         False    0.7669    29

# %%
sns.relplot(data=df, x='contrast', y='test_acc', hue='repeat_noise', col='epoch', kind='line', markers=True, style='repeat_noise' )
# set title
plt.subplots_adjust(top=0.9)
plt.suptitle('Fashion MNIST Accuracy by Epochs and Contrast', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Fashion MNIST Accuracy by Epochs and Contrast')

# %%
a = 1, 2, 3
a
# Out:
# (1, 2, 3)

# %%
def afun(a, b, c):
    print(a, b, c)

# %%
afun(*a)
# Out:
# 1 2 3

# %%
a, *b = 1,2,

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2]
