# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('experimental_data/lateral_recurrence/version_0/metrics.csv')
df
# Out:
#     contrast  epoch  repeat_noise  test_acc  step
# 0        0.8     20          True    0.5024     0
# 1        0.8     50          True    0.5628     1
# 2        0.8     20         False    0.5124     2
# 3        0.8     50         False    0.5372     3
# 4        1.0     20          True    0.5564     4
# 5        1.0     50          True    0.5532     5
# 6        1.0     20         False    0.5320     6
# 7        1.0     50         False    0.5824     7
# 8        0.2     20          True    0.4488     8
# 9        0.2     50          True    0.4568     9
# 10       0.2     20         False    0.3356    10
# 11       0.2     50         False    0.3480    11
# 12       0.4     20          True    0.5172    12
# 13       0.4     50          True    0.5580    13
# 14       0.4     20         False    0.4344    14

# %%
sns.relplot(data=df, x='contrast', y='test_acc', hue='repeat_noise', col='epoch', kind='line', markers=True, style='repeat_noise' )
# set title
plt.subplots_adjust(top=0.9)
plt.suptitle('Fashion MNIST Accuracy by Epochs and Contrast', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Cifar-10 Accuracy by Epochs and Contrast')

# %%
a = 1, 2, 3
a
# Out:
# (1, 2, 3)

# %%
def afun(a, b, c):
    print(a, b, c)

# %%
afun(*a)
# Out:
# 1 2 3

# %%
a, *b = 1,2,

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2]
