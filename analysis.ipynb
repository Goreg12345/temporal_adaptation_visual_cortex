# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('experimental_data/additive_adaptation_80_epochs/metrics.csv')
df
# Out:
#    contrast  epoch  repeat_noise  test_acc  step
# 0       0.2     80          True    0.5240     0
# 1       0.2     80         False    0.3592     1
# 2       0.4     80          True    0.5972     2
# 3       0.4     80         False    0.4404     3
# 4       0.6     80          True    0.6300     4
# 5       0.6     80         False    0.5156     5
# 6       0.8     80          True    0.6556     6
# 7       0.8     80         False    0.5612     7
# 8       1.0     80          True    0.6980     8
# 9       1.0     80         False    0.5816     9

# %%
sns.relplot(data=df, x='contrast', y='test_acc', hue='repeat_noise', col='epoch', kind='line', markers=True, style='repeat_noise' )
# set title
plt.subplots_adjust(top=0.9)
plt.suptitle('Cifar-10 Accuracy by Epochs and Contrast', fontsize=16)
# Out:
# Text(0.5, 0.98, 'Cifar-10 Accuracy by Epochs and Contrast')

# %%
a = 1, 2, 3
a
# Out:
# (1, 2, 3)

# %%
def afun(a, b, c):
    print(a, b, c)

# %%
afun(*a)
# Out:
# 1 2 3

# %%
a, *b = 1,2,

# %%
a
# Out:
# 1

# %%
b
# Out:
# [2]
