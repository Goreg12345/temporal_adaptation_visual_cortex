# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('experimental_data/additive_adaptation/cifar10-10-epochs/metrics.csv')
df
# Out:
#    contrast  repeat_noise  test_acc  step
# 0       0.3          True    0.4080     0
# 1       0.3         False    0.3760     1
# 2       0.6          True    0.4832     2
# 3       0.6         False    0.4744     3
# 4       0.9          True    0.5600     4
# 5       0.9         False    0.5324     5

# %%
sns.pointplot(data=df, x='contrast', y='test_acc', hue='repeat_noise')
# Out:
# <Axes: xlabel='contrast', ylabel='test_acc'>
